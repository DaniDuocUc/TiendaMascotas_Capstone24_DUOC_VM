# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
import joblib
import numpy as np


def calculate_evapotranspiration(df):
    # Constantes
    gamma = 0.065  # Constante psicrométrica (kPa/°C)
    rn_minus_g = 2.0  # Radiación neta menos flujo de calor (MJ/m²/día)
    u2 = 2.0  # Velocidad del viento (m/s)

    # Variables del dataset
    T = df['avg_air_temperature']  # Temperatura del aire (°C)
    RH = df['avg_air_humidity']  # Humedad relativa (%)

    # Cálculo de presión de vapor
    e_s = 0.6108 * np.exp((17.27 * T) / (T + 237.3))  # Saturación (kPa)
    e_a = e_s * (RH / 100)  # Presión real de vapor (kPa)

    # Pendiente de la curva de presión de vapor
    delta = (4098 * e_s) / ((T + 237.3) ** 2)  # (kPa/°C)

    # Cálculo simplificado de ET
    et = (0.408 * delta * rn_minus_g + gamma * (900 / (T + 273)) * u2 * (e_s - e_a)) / \
         (delta + gamma * (1 + 0.34 * u2))

    return et


def predict_evapotranspiration(csv_path: str, model_output: str):
    print('Cargando datos desde', csv_path)

    # Cargar y preparar los datos
    df = pd.read_csv(csv_path)
    df['hour'] = pd.to_datetime(df['hour'], errors="coerce")
    df['evapotranspiration_rate'] = calculate_evapotranspiration(df)
    df = df.dropna()

    # Seleccionar variables relevantes
    X = df[['avg_air_temperature', 'avg_air_humidity', 'avg_soil_humidity']]
    y = df['evapotranspiration_rate']  # Variable objetivo: tasa de ET en mm/hora

    # Dividir los datos en entrenamiento y prueba
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # Crear el modelo de la red neuronal
    model = Sequential([
        Dense(64, input_dim=X_train.shape[1], activation='relu'),  # Capa oculta 1
        Dropout(0.2),  # Regularización para evitar sobreajuste
        Dense(32, activation='relu'),  # Capa oculta 2
        Dropout(0.2),
        Dense(1, activation='linear')  # Capa de salida (predicción continua)
    ])

    # Compilar el modelo
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae'])

    # Entrenar el modelo
    history = model.fit(
        X_train, y_train,
        validation_data=(X_test, y_test),
        epochs=50,
        batch_size=16,
        verbose=1
    )

    # Evaluar el modelo
    loss, mae = model.evaluate(X_test, y_test, verbose=0)
    print(f"Mean Absolute Error (MAE): {mae:.2f}")

    # Hacer predicciones
    y_pred = model.predict(X_test)

    # Comparar predicciones con los valores reales
    results = pd.DataFrame({
        'Actual': y_test.values,
        'Predicted': y_pred.flatten()
    })
    print(results.head())

    # Guardar el modelo
    joblib.dump(model, model_output)
    print(f"Modelo guardado en {model_output}")
# Out:
# Cargando datos desde csv/per_hour.csv
# Epoch 1/50
# C:\Users\gerojasf\Desktop\projects\capstone\farming-smart-analytics\.venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 88.8338 - mae: 7.6256 - val_loss: 9.6627 - val_mae: 2.7924
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 57.2581 - mae: 6.4213 - val_loss: 7.5505 - val_mae: 2.3347
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 49.4325 - mae: 5.3093 - val_loss: 3.7438 - val_mae: 1.7356
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 47.7934 - mae: 5.4788 - val_loss: 2.1806 - val_mae: 1.3784
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 35.9762 - mae: 4.7987 - val_loss: 2.2498 - val_mae: 1.2387
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 30.0057 - mae: 4.6122 - val_loss: 3.7917 - val_mae: 1.7779
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 40.5821 - mae: 5.0099 - val_loss: 2.9303 - val_mae: 1.5251
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 36.8346 - mae: 4.7738 - val_loss: 2.6842 - val_mae: 1.5028
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 24.4933 - mae: 3.8241 - val_loss: 5.2404 - val_mae: 2.1712
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 23.6474 - mae: 3.6163 - val_loss: 4.4980 - val_mae: 2.0031
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 23.7849 - mae: 3.7427 - val_loss: 3.5561 - val_mae: 1.7518
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 28.3191 - mae: 4.0505 - val_loss: 3.8049 - val_mae: 1.8241
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 18.0878 - mae: 3.3600 - val_loss: 3.0758 - val_mae: 1.6207
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 23.1808 - mae: 3.5019 - val_loss: 2.8344 - val_mae: 1.5488
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16.2553 - mae: 3.1032 - val_loss: 2.8551 - val_mae: 1.5504
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 15.2731 - mae: 3.1473 - val_loss: 3.0333 - val_mae: 1.6012
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 10.8215 - mae: 2.4818 - val_loss: 2.6637 - val_mae: 1.4851
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 21.9731 - mae: 3.5657 - val_loss: 2.1306 - val_mae: 1.2730
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 11.0157 - mae: 2.6126 - val_loss: 1.8913 - val_mae: 1.1968
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 11.0360 - mae: 2.5204 - val_loss: 1.7793 - val_mae: 1.1427
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7818 - mae: 1.9198 - val_loss: 1.8386 - val_mae: 1.1692
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.9244 - mae: 2.3619 - val_loss: 2.1223 - val_mae: 1.2920
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 11.9827 - mae: 2.6460 - val_loss: 2.1886 - val_mae: 1.3144
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.8705 - mae: 2.7731 - val_loss: 2.5770 - val_mae: 1.4405
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.9872 - mae: 2.0544 - val_loss: 2.5670 - val_mae: 1.4217
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.7240 - mae: 1.6240 - val_loss: 2.5491 - val_mae: 1.4003
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.6345 - mae: 2.1583 - val_loss: 2.4386 - val_mae: 1.3430
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.9535 - mae: 2.0985 - val_loss: 2.3202 - val_mae: 1.2804
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.1069 - mae: 1.9123 - val_loss: 1.9264 - val_mae: 1.1300
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.0970 - mae: 1.8365 - val_loss: 1.6820 - val_mae: 1.0309
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.3801 - mae: 1.7252 - val_loss: 1.6317 - val_mae: 1.0064
# Epoch 32/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 10.1434 - mae: 2.3362 - val_loss: 1.6927 - val_mae: 1.0277
# Epoch 33/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4995 - mae: 1.5821 - val_loss: 1.7427 - val_mae: 1.0471
# Epoch 34/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.4344 - mae: 1.9179 - val_loss: 1.6949 - val_mae: 1.0321
# Epoch 35/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.7941 - mae: 1.5705 - val_loss: 1.7871 - val_mae: 1.0794
# Epoch 36/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.9099 - mae: 1.7691 - val_loss: 1.8382 - val_mae: 1.1210
# Epoch 37/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.5023 - mae: 1.7603 - val_loss: 1.8543 - val_mae: 1.1520
# Epoch 38/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.4362 - mae: 1.5692 - val_loss: 1.8290 - val_mae: 1.1607
# Epoch 39/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.5797 - mae: 1.6760 - val_loss: 1.8358 - val_mae: 1.1704
# Epoch 40/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.8328 - mae: 1.7519 - val_loss: 1.9311 - val_mae: 1.2106
# Epoch 41/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.1307 - mae: 1.6668 - val_loss: 1.7280 - val_mae: 1.1240
# Epoch 42/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.5242 - mae: 1.5548 - val_loss: 1.5059 - val_mae: 1.0258
# Epoch 43/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.3188 - mae: 1.4238 - val_loss: 1.3683 - val_mae: 0.9657
# Epoch 44/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.5339 - mae: 1.4286 - val_loss: 1.4466 - val_mae: 1.0155
# Epoch 45/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.8141 - mae: 1.2996 - val_loss: 1.5675 - val_mae: 1.0738
# Epoch 46/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.2838 - mae: 1.4562 - val_loss: 1.7152 - val_mae: 1.1504
# Epoch 47/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.2791 - mae: 1.4268 - val_loss: 1.7066 - val_mae: 1.1524
# Epoch 48/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.1860 - mae: 1.4303 - val_loss: 1.6333 - val_mae: 1.1239
# Epoch 49/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.8211 - mae: 1.3941 - val_loss: 1.6617 - val_mae: 1.1422
# Epoch 50/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.7960 - mae: 1.6207 - val_loss: 1.8333 - val_mae: 1.2157
# Mean Absolute Error (MAE): 1.22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#      Actual  Predicted
# 0  4.078638   2.851430
# 1  3.867541   2.693583
# 2  1.335732   0.571337
# 3  2.101362   0.810858
# 4  1.391813   0.754530
# Modelo guardado en ml/model_04_device_id_1
